# %% [markdown]
# # Modelling

# %%
# Analysis
import pandas as pd
import numpy as np

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Linear Models

# %%
houses = {'area' : [40, 50, 60, 70, 80], 
          'price': [120000, 150000, 200000, 
                    250000, 300000]}
df = pd.DataFrame(houses)
plt.xlabel('Area (metres sq.)')
plt.ylabel('Price (€)')
sns.scatterplot(data=df, x='area', y='price')
plt.show()

# %%
sns.lmplot(x='area',y='price',data=df)
plt.xlabel('Area (metres sq.)')
plt.ylabel('Price (€)')
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip');

# %%
sns.lmplot(data=tips, x='total_bill', y='tip');

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker');

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', col='smoker');

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', col='smoker', row='time');

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker', col='sex', row='time');

# %%
sns.lmplot(data=tips, x='size', y='tip', x_jitter=0.05);

# %%
sns.lmplot(data=tips, x='size', y='tip', x_estimator=np.mean, ci=90);

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Joint Plot

# %% [markdown]
# We can get a quick overview of how each feature varies relative to each other.

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data=penguins, x='bill_length_mm', y='flipper_length_mm',kind='reg')

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# A pairplot will plot each numerical feature against one another as a matrix

# %%
sns.pairplot(penguins, hue='island', kind='reg');

# %% [markdown]
# Using the `corr()` method, we can get measurements of how each feature are correlated to one another. This is then plotted on a heatmap.

# %%
sns.heatmap(penguins.corr(), annot=True, cmap='Blues');
# Out:
# C:\Users\GonzalezC\AppData\Local\Temp\ipykernel_12868\230667996.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(penguins.corr(), annot=True, cmap='Blues');

# %%
tips = sns.load_dataset('tips')
sns.heatmap(tips.corr(), annot=True, cmap='Blues');
# Out:
# C:\Users\GonzalezC\AppData\Local\Temp\ipykernel_12868\2248354667.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), annot=True, cmap='Blues');

# %% [markdown]
# ### Modelled Line Plot

# %% [markdown]
# When using the Line Plot, Matplotlib will try to connect every data point. However, Seaborn will make an effort to fit a trend line to the data.

# %%
summer2016 = pd.read_csv('data/summer2016.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 summer2016 = pd.read_csv('data/summer2016.csv')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
plt.plot(summer2016['Height'], summer2016['Weight'])

# %%
summer2016 = pd.read_csv('data/summer2016.csv')
sns.lineplot(data=summer2016, x='Height', y='Weight')
